# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from datetime import datetime
import re
import pytz

# %%
from operator import itemgetter
from urllib.parse import urlparse

# %% [markdown]
# #### Helper functions to parse the server logs

# %%
# Parse string and return the string delimited by 2 characters
def parseString(s):
    if s is None:
        return s[1:-1]

# 
def parseInt(s):
    if s is None:
        return 0
    try:
        return int(s)
    except ValueError:
        return 0
    
def parseDatetime(s):
    try:
        date = datetime.strptime(s[1:-7], '%d/%b/%Y:%H:%M:%S')
        timezone = int(s[-6:-3])*60+int(s[-3:-1])
        return date.replace(tzinfo=pytz.FixedOffset(timezone))
    except ValueError:
        return '-'

# %%
# Dict of functions for converting values in the logs.
data_converters = {'time': parseDatetime,
        'request': parseString,
        'status': parseInt,
        'size': parseInt,
        'referer': parseString,
        'user_agent': parseString}

# %%
server_logs = pd.read_csv('/content/drive/MyDrive/ML_Datasets/Web Server Logs/web-server-logs.txt',
                   usecols=[0, 3, 4, 5, 6, 7, 8],
                   names=['Users_IP', 'Timestamp','Requested_Page', 'HTTP_Code', 'Page_Size', 'Referrer_Page','User_Agent'],
                   header=None,
                   error_bad_lines=False,
                   engine='python',
                   na_values='-',
                   converters=data_converters,
                   sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])')

# %%
server_logs.head()
# Out:
#          Users_IP  ...                                         User_Agent
# 0     13.66.139.0  ...  "Mozilla/5.0 (compatible; bingbot/2.0; +http:/...
# 1  157.48.153.185  ...  "Mozilla/5.0 (Windows NT 6.3; Win64; x64) Appl...
# 2  157.48.153.185  ...  "Mozilla/5.0 (Windows NT 6.3; Win64; x64) Appl...
# 3  216.244.66.230  ...  "Mozilla/5.0 (compatible; DotBot/1.1; http://w...
# 4    54.36.148.92  ...  "Mozilla/5.0 (compatible; AhrefsBot/7.0; +http...
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Q1

# %% [markdown]
# #### Find 10 people who visited the site frequently, show the information that identify the people and state why you identify these people as frequent visitors

# %%
user_IP_addresses = set(server_logs['Users_IP'])
print(len(user_IP_addresses))
user_devices=set(server_logs['User_Agent'])
len(user_devices)
# Out:
# 6298
# 2520

# %%
user_device = {}
for i,row in server_logs.iterrows():
    if(tuple((row['Users_IP'],row['User_Agent'])) in user_device):
        user_device[tuple((row['Users_IP'],row['User_Agent']))] += 1
    
    else:
        user_device[tuple((row['Users_IP'],row['User_Agent']))] = 1

# %%
frequent_users = dict(sorted(user_device.items(), key = itemgetter(1), reverse = True)[:10])

# %%
frequent_users
# Out:
# {('173.255.176.5',
#   '"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:82.0) Gecko/20100101 Firefox/82.0"'): 2663,
#  ('173.255.176.5',
#   '"Mozilla/5.0 (compatible; 008/0.83; http://www.80legs.com/webcrawler.html) Gecko/2008032620"'): 1678,
#  ('178.44.47.170', '"python-requests/2.25.1"'): 2774,
#  ('193.106.31.130',
#   '"Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0)"'): 136543,
#  ('193.9.114.182',
#   '"Mozilla/5.0 (Windows; U; Windows NT 5.1; ru; rv:1.9.2.3) Gecko/20100401 Firefox/3.6.3"'): 1986,
#  ('197.52.128.37',
#   '"Mozilla/5.0 (Windows NT 6.1; Trident/7.0; rv:11.0) like Gecko"'): 40771,
#  ('45.15.143.155',
#   '"Mozilla/5.0 (X11; Ubuntu; Linux i686; rv:28.0) Gecko/20100101 Firefox/28.0"'): 1284,
#  ('45.15.143.155', '"python-requests/2.25.0"'): 642,
#  ('51.210.183.78', '"curl/7.68.0"'): 2684,
#  ('62.138.3.52',
#   '"Mozilla/5.0 (X11; Linux x86_64; rv:81.0) Gecko/20100101 Firefox/81.0"'): 634}

# %% [markdown]
# ### Q2

# %% [markdown]
# #### Show at least five sessions and the page views per each session.

# %%
timestamp = []
pages_requested = []
users_details = []

for i in list(user_device)[:200]:
    for j,row in server_logs.iterrows():
        if(i==tuple((row['Users_IP'],row['User_Agent']))):
            timestamp.append(row['Timestamp'])
            pages_requested.append(row['Requested_Page'])
            users_details.append(i)

# %%
timestamp[:3]
# Out:
# ['[19/Dec/2020:13:57:26 +0100]',
#  '[22/Jan/2021:01:57:53 +0100]',
#  '[07/Feb/2021:18:59:27 +0100]']

# %%
pages_requested[:3]
# Out:
# ['"GET /index.php?option=com_phocagallery&view=category&id=1:almhuette-raith&Itemid=53 HTTP/1.1"',
#  '"GET /index.php?option=com_phocagallery&view=category&id=1:almhuette-raith&Itemid=53 HTTP/1.1"',
#  '"GET /index.php?option=com_content&view=article&id=46&Itemid=54 HTTP/1.1"']

# %%
users_details[:3]
# Out:
# [('13.66.139.0',
#   '"Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)"'),
#  ('13.66.139.0',
#   '"Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)"'),
#  ('13.66.139.0',
#   '"Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)"')]

# %%
sessions = pd.DataFrame(data={'Session_Time': timestamp, 'Pages_Requested':pages_requested, 'User_Details': users_details})

# %%
sessions.head()
# Out:
#                    Session_Time  ...                                       User_Details
# 0  [19/Dec/2020:13:57:26 +0100]  ...  (13.66.139.0, "Mozilla/5.0 (compatible; bingbo...
# 1  [22/Jan/2021:01:57:53 +0100]  ...  (13.66.139.0, "Mozilla/5.0 (compatible; bingbo...
# 2  [07/Feb/2021:18:59:27 +0100]  ...  (13.66.139.0, "Mozilla/5.0 (compatible; bingbo...
# 3  [11/Mar/2021:07:37:22 +0100]  ...  (13.66.139.0, "Mozilla/5.0 (compatible; bingbo...
# 4  [19/Dec/2020:14:08:06 +0100]  ...  (157.48.153.185, "Mozilla/5.0 (Windows NT 6.3;...
#
# [5 rows x 3 columns]

# %% [markdown]
# ### Q3

# %% [markdown]
# #### Show five frequent pages which the users visit before visiting this particular web site

# %%
referrer_pages = server_logs['Referrer_Page'].dropna(how='all')

parsed_referrer_pages = []

for i in referrer_pages:       
    url = urlparse(i.replace('"', ''))
    res = '{uri.scheme}://{uri.netloc}/'.format(uri=url)
    parsed_referrer_pages.append(res)

# %%
word_counter = {}

for url in parsed_referrer_pages:
    if url in word_counter:
        word_counter[url] += 1
    else:
        word_counter[url] = 1

# %%
frequent_pages = sorted(word_counter, key = word_counter.get, reverse = True)

top_5_pages = frequent_pages[:6]

for i in top_5_pages:
    if(i==':///'''):
        top_5_pages.remove(i)
        
for i,j in enumerate(top_5_pages, start=1):
    print(i,"",j)
# Out:
# 1  http://www.almhuette-raith.at/
# 2  http://almhuette-raith.at/
# 3  https://www.google.com/
# 4  http://simplesite.com/
# 5  http://www.google.com/

# %% [markdown]
# ### Q4

# %% [markdown]
# #### Find at least ten frequent sequential patterns or navigational patterns which the users follow using the GSP algorithm, state your own support value and maximum length of item_set.

# %%
requested_paged = list(sessions['Pages_Requested'])
accessed_pages = {}

for i,row in sessions.iterrows():
    if(row['User_Details'] in accessed_pages):
        accessed_pages[row['User_Details']].append(row['Pages_Requested'])    
    else:
        accessed_pages[row['User_Details']] = [row['Pages_Requested']]
        
for i in accessed_pages:
    print('\n Client {} accessed these pages \n {} \n'.format(i,accessed_pages[i]))
all_pages=[]
for i in accessed_pages:
    all_pages.append(accessed_pages[i])
# Out:
#  Client ('13.66.139.0', '"Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)"') accessed these pages
#  ['"GET /index.php?option=com_phocagallery&view=category&id=1:almhuette-raith&Itemid=53 HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1:almhuette-raith&Itemid=53 HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=46&Itemid=54 HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=46&Itemid=54 HTTP/1.1"']
#
#
#  Client ('157.48.153.185', '"Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('216.244.66.230', '"Mozilla/5.0 (compatible; DotBot/1.1; http://www.opensiteexplorer.org/dotbot, help@moz.com)"') accessed these pages
#  ['"GET /robots.txt HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=50&Itemid=56 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /apache-log/?S=A HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=46&Itemid=54 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /apache-log/?M=A HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /apache-log/?S=A HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /apache-log/?M=D HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /index.php?option=com_content&amp;view=frontpage HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /apache-log/?S=D HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /apache-log/?N=A HTTP/1.1"', '"GET /apache-log/?D=D HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /index.php?option=com_mailto&tmpl=component&link=b35d5fbd58e835b514ed0fc0df0ee23cd3272321 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /apache-log/ HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1&Itemid=53%22 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /index.php?option=com_content&view=frontpage HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=50&Itemid=56 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /apache-log/?N=D HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /apache-log/access.log:80 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /%22 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1&Itemid=53 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=46&Itemid=54 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=4:ferienwohnung2&Itemid=53%22 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1&Itemid=53 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1&Itemid=53&limitstart=20 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1&Itemid=53&limitstart=20 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=49&Itemid=55 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=49&Itemid=55 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"']
#
#
#  Client ('54.36.148.92', '"Mozilla/5.0 (compatible; AhrefsBot/7.0; +http://ahrefs.com/robot/)"') accessed these pages
#  ['"GET /index.php?option=com_phocagallery&view=category&id=2%3Awinterfotos&Itemid=53 HTTP/1.1"', '"GET /apache-log/error.log HTTP/1.1"']
#
#
#  Client ('92.101.35.224', '"Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; .NET CLR 1.1.4322)"') accessed these pages
#  ['"GET /administrator/index.php HTTP/1.1"']
#
#
#  Client ('73.166.162.225', '"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.101 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('54.36.148.108', '"Mozilla/5.0 (compatible; AhrefsBot/7.0; +http://ahrefs.com/robot/)"') accessed these pages
#  ['"GET /robots.txt HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=50&Itemid=56 HTTP/1.1"']
#
#
#  Client ('54.36.148.1', '"Mozilla/5.0 (compatible; AhrefsBot/7.0; +http://ahrefs.com/robot/)"') accessed these pages
#  ['"GET /index.php?option=com_phocagallery&view=category&id=2%3Awinterfotos&Itemid=53 HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1:almhuette-raith&Itemid=53 HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=50&Itemid=56 HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=50&Itemid=56 HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1&Itemid=53 HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=50&Itemid=56 HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1&Itemid=53&limitstart=20 HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=3:almhuette-raith&Itemid=53 HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=4:ferienwohnung2&Itemid=53 HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=2%3Awinterfotos&Itemid=53&limitstart=20 HTTP/1.1"', '"GET /apache-log/ HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=46&Itemid=54 HTTP/1.1"', '"GET /apache-log/?N=A HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1&Itemid=53 HTTP/1.1"', '"GET /apache-log/?S=A HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1%3Aalmhuette-raith&Itemid=53 HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=50&Itemid=56 HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1&Itemid=53 HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1%3Aalmhuette-raith&Itemid=53&limitstart=20 HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=3:almhuette-raith&Itemid=53 HTTP/1.1"', '"GET /apache-log/?D=A HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=2%3Awinterfotos&Itemid=53&limitstart=20 HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=46&Itemid=54 HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=49&Itemid=55 HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=49&Itemid=55 HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=4:ferienwohnung2&Itemid=53 HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /apache-log/?S=A HTTP/1.1"', '"GET /apache-log/ HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=46&Itemid=54 HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=49&Itemid=55 HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1:almhuette-raith&Itemid=53 HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1&Itemid=53 HTTP/1.1"', '"GET /apache-log/?S=A HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=2%3Awinterfotos&Itemid=53&limitstart=20 HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=2%3Awinterfotos&Itemid=53 HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1%3Aalmhuette-raith&Itemid=53&limitstart=20 HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1%3Aalmhuette-raith&Itemid=53 HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1%3Aalmhuette-raith&Itemid=53&limitstart=20 HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /apache-log/?D=D HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=49&Itemid=55 HTTP/1.1"', '"GET /apache-log/?N=D HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1:almhuette-raith&Itemid=53 HTTP/1.1"', '"GET / HTTP/1.1"']
#
#
#  Client ('162.158.203.24', '"-"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"']
#
#
#  Client ('35.237.4.214', '"Mozilla/5.0 (compatible; Discordbot/2.0; +https://discordapp.com)"') accessed these pages
#  ['"GET /administrator/%22 HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /apache-log/error.log HTTP/1.1"']
#
#
#  Client ('42.236.10.125', '"Mozilla/5.0 (Linux; U; Android 8.1.0; zh-CN; EML-AL00 Build/HUAWEIEML-AL00) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/57.0.2987.108 baidu.sogo.uc.UCBrowser/11.9.4.974 UWS/2.13.1.48 Mobile Safari/537.36 AliApp(DingTalk/4.5.11) com.alibaba.android.rimet/10487439 Channel/227200 language/zh-CN"') accessed these pages
#  ['"GET / HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/css/bowslideshow.css HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /templates/jp_hotel/css/template.css HTTP/1.1"', '"GET /media/system/js/caption.js HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_01.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_06.jpg HTTP/1.1"', '"GET /templates/jp_hotel/images/logo.jpg HTTP/1.1"', '"GET /images/stories/raith/garage.jpg HTTP/1.1"', '"GET /images/stories/raith/almenland_logo.jpg HTTP/1.1"', '"GET /images/stories/raith/oststeiermark.png HTTP/1.1"', '"GET /images/stories/raith/steiermark_herz.png HTTP/1.1"', '"GET /images/bg_raith.jpg HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/images/image_shadow.png HTTP/1.1"', '"GET /templates/jp_hotel/css/suckerfish.css HTTP/1.1"', '"GET /media/system/js/mootools.js HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_01.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_06.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_07.jpg HTTP/1.1"', '"GET /images/stories/raith/almenland_logo.jpg HTTP/1.1"', '"GET /images/stories/raith/oststeiermark.png HTTP/1.1"', '"GET /templates/jp_hotel/images/logo.jpg HTTP/1.1"', '"GET /images/stories/raith/grillplatz.jpg HTTP/1.1"', '"GET /images/stories/raith/garage.jpg HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /templates/jp_hotel/css/layout.css HTTP/1.1"', '"GET /templates/jp_hotel/js/moomenu.js HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_01.jpg HTTP/1.1"', '"GET /images/bg_raith.jpg HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/css/bowslideshow.css HTTP/1.1"', '"GET /media/system/js/mootools.js HTTP/1.1"', '"GET /templates/jp_hotel/css/template.css HTTP/1.1"', '"GET /templates/jp_hotel/css/layout.css HTTP/1.1"', '"GET /templates/jp_hotel/css/suckerfish.css HTTP/1.1"', '"GET /templates/jp_hotel/js/moomenu.js HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/js/sliderman.1.3.0.js HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/css/bowslideshow.css HTTP/1.1"', '"GET /media/system/js/caption.js HTTP/1.1"', '"GET /media/system/js/mootools.js HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /images/stories/raith/almhuette_raith.jpg HTTP/1.1"', '"GET /images/stories/raith/steiermark_herz.png HTTP/1.1"', '"GET /templates/jp_hotel/images/content_heading.gif HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /media/system/js/caption.js HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_01.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_05.jpg HTTP/1.1"', '"GET /images/stories/raith/almenland_logo.jpg HTTP/1.1"', '"GET /templates/jp_hotel/css/menu.css HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/js/sliderman.1.3.0.js HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_06.jpg HTTP/1.1"', '"GET /images/stories/raith/grillplatz.jpg HTTP/1.1"', '"GET /images/stories/raith/steiermark_herz.png HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /media/system/js/caption.js HTTP/1.1"', '"GET /images/stories/raith/oststeiermark.png HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_07.jpg HTTP/1.1"', '"GET /templates/jp_hotel/css/menu.css HTTP/1.1"', '"GET /images/stories/raith/almenland_logo.jpg HTTP/1.1"', '"GET /images/stories/raith/steiermark_herz.png HTTP/1.1"', '"GET /templates/jp_hotel/images/content_heading.gif HTTP/1.1"', '"GET /images/bg_raith.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_05.jpg HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/css/bowslideshow.css HTTP/1.1"', '"GET /media/system/js/caption.js HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_05.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_07.jpg HTTP/1.1"', '"GET /images/stories/raith/grillplatz.jpg HTTP/1. ...
#
#
#  Client ('42.236.10.117', '"Mozilla/5.0 (Linux; U; Android 8.1.0; zh-CN; EML-AL00 Build/HUAWEIEML-AL00) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/57.0.2987.108 baidu.sogo.uc.UCBrowser/11.9.4.974 UWS/2.13.1.48 Mobile Safari/537.36 AliApp(DingTalk/4.5.11) com.alibaba.android.rimet/10487439 Channel/227200 language/zh-CN"') accessed these pages
#  ['"GET /templates/jp_hotel/css/layout.css HTTP/1.1"', '"GET /media/system/js/mootools.js HTTP/1.1"', '"GET /templates/jp_hotel/js/moomenu.js HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_04.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_05.jpg HTTP/1.1"', '"GET /images/stories/raith/almhuette_raith.jpg HTTP/1.1"', '"GET /images/stories/raith/wohnraum.jpg HTTP/1.1"', '"GET /templates/jp_hotel/images/module_heading.gif HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/css/bowslideshow.css HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /templates/jp_hotel/css/template.css HTTP/1.1"', '"GET /templates/jp_hotel/css/layout.css HTTP/1.1"', '"GET /templates/jp_hotel/css/menu.css HTTP/1.1"', '"GET /media/system/js/caption.js HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_05.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_04.jpg HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/images/image_shadow.png HTTP/1.1"', '"GET /images/stories/raith/almhuette_raith.jpg HTTP/1.1"', '"GET /images/stories/raith/steiermark_herz.png HTTP/1.1"', '"GET /templates/jp_hotel/css/layout.css HTTP/1.1"', '"GET /templates/jp_hotel/css/suckerfish.css HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/js/sliderman.1.3.0.js HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_03.jpg HTTP/1.1"', '"GET /images/stories/raith/almhuette_raith.jpg HTTP/1.1"', '"GET /templates/jp_hotel/css/template.css HTTP/1.1"', '"GET /templates/jp_hotel/css/layout.css HTTP/1.1"', '"GET /media/system/js/mootools.js HTTP/1.1"', '"GET /media/system/js/caption.js HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /media/system/js/caption.js HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /templates/jp_hotel/images/logo.jpg HTTP/1.1"', '"GET /images/stories/raith/almenland_logo.jpg HTTP/1.1"', '"GET /images/stories/raith/oststeiermark.png HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /templates/jp_hotel/css/template.css HTTP/1.1"', '"GET /templates/jp_hotel/css/layout.css HTTP/1.1"', '"GET /templates/jp_hotel/js/moomenu.js HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_03.jpg HTTP/1.1"', '"GET /images/stories/raith/almenland_logo.jpg HTTP/1.1"', '"GET /images/stories/raith/oststeiermark.png HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/images/image_shadow.png HTTP/1.1"', '"GET /images/bg_raith.jpg HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/css/bowslideshow.css HTTP/1.1"', '"GET /templates/jp_hotel/css/suckerfish.css HTTP/1.1"', '"GET /media/system/js/mootools.js HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_03.jpg HTTP/1.1"', '"GET /images/bg_raith.jpg HTTP/1.1"', '"GET /templates/jp_hotel/css/suckerfish.css HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_02.jpg HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /images/stories/raith/garage.jpg HTTP/1.1"', '"GET /images/stories/raith/oststeiermark.png HTTP/1.1"', '"GET /templates/jp_hotel/css/menu.css HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/css/bowslideshow.css HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /templates/jp_hotel/css/suckerfish.css HTTP/1.1"', '"GET /media/system/js/caption.js HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_05.jpg HTTP/1.1"', '"GET /images/bg_raith.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_01.jpg HTTP/1.1"', '"GET /media/system/js/mootools.js HTTP/1.1"', '"GET /templates/jp_hotel/images/logo.jpg HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/images/image_shadow.png HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_04.jpg HTTP/1.1"', '"GET /templates/jp_hotel/css/template.css HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_02.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_03.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_04.jpg HTTP/1.1"', ...
#
#
#  Client ('42.236.10.114', '"Mozilla/5.0 (Linux; U; Android 8.1.0; zh-CN; EML-AL00 Build/HUAWEIEML-AL00) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/57.0.2987.108 baidu.sogo.uc.UCBrowser/11.9.4.974 UWS/2.13.1.48 Mobile Safari/537.36 AliApp(DingTalk/4.5.11) com.alibaba.android.rimet/10487439 Channel/227200 language/zh-CN"') accessed these pages
#  ['"GET /templates/jp_hotel/css/menu.css HTTP/1.1"', '"GET /templates/jp_hotel/css/suckerfish.css HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/js/sliderman.1.3.0.js HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_02.jpg HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_03.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_07.jpg HTTP/1.1"', '"GET /images/stories/raith/grillplatz.jpg HTTP/1.1"', '"GET /templates/jp_hotel/images/content_heading.gif HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /templates/jp_hotel/js/moomenu.js HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/js/sliderman.1.3.0.js HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_03.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_02.jpg HTTP/1.1"', '"GET /templates/jp_hotel/images/content_heading.gif HTTP/1.1"', '"GET /images/bg_raith.jpg HTTP/1.1"', '"GET /templates/jp_hotel/images/module_heading.gif HTTP/1.1"', '"GET /images/stories/raith/wohnraum.jpg HTTP/1.1"', '"GET /templates/jp_hotel/css/template.css HTTP/1.1"', '"GET /templates/jp_hotel/css/menu.css HTTP/1.1"', '"GET /templates/jp_hotel/css/suckerfish.css HTTP/1.1"', '"GET /templates/jp_hotel/css/menu.css HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/js/sliderman.1.3.0.js HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_01.jpg HTTP/1.1"', '"GET /templates/jp_hotel/images/logo.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_06.jpg HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /templates/jp_hotel/css/layout.css HTTP/1.1"', '"GET /templates/jp_hotel/js/moomenu.js HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_02.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_06.jpg HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/images/image_shadow.png HTTP/1.1"', '"GET /images/stories/raith/almhuette_raith.jpg HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /media/system/js/caption.js HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_05.jpg HTTP/1.1"', '"GET /templates/jp_hotel/images/logo.jpg HTTP/1.1"', '"GET /templates/jp_hotel/images/content_heading.gif HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/images/image_shadow.png HTTP/1.1"', '"GET /templates/jp_hotel/css/template.css HTTP/1.1"', '"GET /templates/jp_hotel/css/layout.css HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/js/sliderman.1.3.0.js HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_03.jpg HTTP/1.1"', '"GET /templates/jp_hotel/images/content_heading.gif HTTP/1.1"', '"GET /images/stories/raith/oststeiermark.png HTTP/1.1"', '"GET /images/stories/raith/grillplatz.jpg HTTP/1.1"', '"GET /templates/jp_hotel/css/template.css HTTP/1.1"', '"GET /templates/jp_hotel/css/suckerfish.css HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/js/sliderman.1.3.0.js HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_01.jpg HTTP/1.1"', '"GET /images/stories/raith/almhuette_raith.jpg HTTP/1.1"', '"GET /templates/jp_hotel/images/module_heading.gif HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_06.jpg HTTP/1.1"', '"GET /templates/jp_hotel/css/menu.css HTTP/1.1"', '"GET /templates/jp_hotel/css/suckerfish.css HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /media/system/js/mootools.js HTTP/1.1"', '"GET /templates/jp_hotel/css/layout.css HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/js/sliderman.1.3.0.js HTTP/1.1"', '"GET /templates/jp_hotel/js/moomenu.js HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_06.jpg HTTP/1.1"', '"GET /templates/jp_hotel/images/logo.jpg HTTP/1.1"', '"GET /images/stories/raith/wohnraum.jpg HTTP/1.1"', '"GET /images/stories/raith/almenland_logo.jpg HTTP/1.1"', '"GET /images/stories/raith/steiermark_herz.png HTTP/1.1"', '"G ...
#
#
#  Client ('191.102.167.138', '"Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.139 Safari/537.36"') accessed these pages
#  ['"GET / HTTP/1.0"']
#
#
#  Client ('54.36.149.55', '"Mozilla/5.0 (compatible; AhrefsBot/7.0; +http://ahrefs.com/robot/)"') accessed these pages
#  ['"GET /index.php?option=com_content&view=article&id=46&Itemid=54 HTTP/1.1"']
#
#
#  Client ('95.217.229.86', '"Mozilla/5.0 (compatible; Seekport Crawler; http://seekport.com/"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"', '"GET / HTTP/1.1"']
#
#
#  Client ('182.239.117.249', '"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('182.239.117.249', '"Wget/1.20.3 (linux-gnu)"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"']
#
#
#  Client ('66.249.64.41', '"Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"') accessed these pages
#  ['"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /index.old1 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /robots.txt HTTP/1.1"']
#
#
#  Client ('157.48.208.79', '"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"']
#
#
#  Client ('162.210.196.129', '"Mozilla/5.0 (compatible; MJ12bot/v1.4.8; http://mj12bot.com/)"') accessed these pages
#  ['"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"']
#
#
#  Client ('66.249.66.158', '"Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Build/MMB29P) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.90 Mobile Safari/537.36 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"') accessed these pages
#  ['"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /apache-log/error.log HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /apache-log/ HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1&Itemid=53 HTTP/1.1"']
#
#
#  Client ('45.145.161.12', '"Mozilla/5.0(Linux;Android9;SM-A505FN)AppleWebKit/537.36(KHTML,likeGecko)Chrome/71.0.3578.99MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.51.36', '"Mozilla/5.0(Linux;Android9;SM-G955F)AppleWebKit/537.36(KHTML,likeGecko)Chrome/84.0.4147.125MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.138.145.131', '"Mozilla/5.0(iPad;CPUOS13_6likeMacOSX)AppleWebKit/605.1.15(KHTML,likeGecko)GSA/114.0.318129667Mobile/15E148Safari/604.1"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.144.0.179', '"Mozilla/5.0(Linux;Android4.2.1;en-us;Nexus5Build/JOP40D)AppleWebKit/535.19(KHTML,likeGecko;googleweblight)Chrome/38.0.1025.166MobileSafari/535.19"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.138.145.131', '"Mozilla/5.0(Macintosh;IntelMacOSX10_13_6)AppleWebKit/537.36(KHTML,likeGecko)Chrome/68.0.3440.106Safari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('194.156.95.52', '"Mozilla/5.0(WindowsNT10.0;Win64;x64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/84.0.4147.105Safari/537.36OPR/70.0.3728.106"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.51.36', '"Mozilla/5.0(Linux;Android10;SM-G965F)AppleWebKit/537.36(KHTML,likeGecko)Chrome/81.0.4044.117MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.153.227.31', '"Mozilla/5.0(WindowsNT10.0)AppleWebKit/537.36(KHTML,likeGecko)Chrome/51.0.2683.0Safari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.51.36', '"Mozilla/5.0(Linux;Android9;W-K510-BYT)AppleWebKit/537.36(KHTML,likeGecko)Chrome/84.0.4147.125MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.51.36', '"Mozilla/5.0(Linux;Android10;SAMSUNGSM-A505FN)AppleWebKit/537.36(KHTML,likeGecko)SamsungBrowser/12.1Chrome/79.0.3945.136MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.138.4.22', '"Mozilla/5.0(Linux;Android10;SM-A3050)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('87.247.143.24', '"Mozilla/5.0(Linux;Android9;STK-LX1Build/HUAWEISTK-LX1;wv)AppleWebKit/537.36(KHTML,likeGecko)Version/4.0Chrome/79.0.3945.116MobileSafari/537.36EdgW/1.0"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.144.0.98', '"Mozilla/5.0(Linux;Android10;SM-A705FN)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.51.62', '"Mozilla/5.0(iPhone;CPUiPhoneOS13_3_1likeMacOSX)AppleWebKit/605.1.15(KHTML,likeGecko)Version/13.0.5Mobile/15E148Safari/604.1"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.51.36', '"Mozilla/5.0(Linux;Android10;SAMSUNGSM-G980F/G980FXXU4BTH5)AppleWebKit/537.36(KHTML,likeGecko)SamsungBrowser/12.1Chrome/79.0.3945.136MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.144.0.98', '"Mozilla/5.0(Linux;U;Android9;fr-fr;Redmi7Build/PKQ1.181021.001)AppleWebKit/537.36(KHTML,likeGecko)Version/4.0Chrome/71.0.3578.141MobileSafari/537.36XiaoMi/MiuiBrowser/12.5.2-gn"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('176.222.58.254', '"Mozilla/5.0(Macintosh;IntelMacOSX10_7_5)AppleWebKit/537.36(KHTML,likeGecko)Chrome/49.0.2623.112Safari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.51.62', '"Mozilla/5.0(WindowsNT10.0;Win64;x64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/83.0.4103.116Safari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.153.227.31', '"Mozilla/5.0(Linux;Android5.0.1;SAMSUNGGT-I9505)AppleWebKit/537.36(KHTML,likeGecko)SamsungBrowser/12.1Chrome/79.0.3945.136MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.144.0.179', '"Mozilla/5.0(Linux;Android7.0;G3311Build/43.0.A.7.106;wv)AppleWebKit/537.36(KHTML,likeGecko)Version/4.0Chrome/85.0.4183.81MobileSafari/537.36EdgW/1.0"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('176.222.58.254', '"Mozilla/5.0(Linux;Android10;Nokia7plus)AppleWebKit/537.36(KHTML,likeGecko)Chrome/84.0.4147.111MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('194.156.95.52', '"Mozilla/5.0(Linux;Android8.0.0;SAMSUNGSM-G930F)AppleWebKit/537.36(KHTML,likeGecko)SamsungBrowser/12.0Chrome/79.0.3945.136MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.144.0.98', '"Mozilla/5.0(Linux;Android10;Nokia1.3)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('176.222.58.90', '"Mozilla/5.0(Linux;Android5.0.1;YOGATablet2-1050L)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81Safari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.51.36', '"Mozilla/5.0(WindowsNT10.0;Win64;x64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/64.0.3282.140Safari/537.36Edge/18.17763"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.207.154', '"Mozilla/5.0(Linux;Android10;SM-G960F)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('194.156.95.52', '"Mozilla/5.0(Linux;Android9;LM-K410)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.51.62', '"Mozilla/5.0(iPhone;CPUiPhoneOS12_4_8likeMacOSX)AppleWebKit/605.1.15(KHTML,likeGecko)Version/12.1.2Mobile/15E148Safari/604.1"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.138.145.131', '"Mozilla/5.0(WindowsNT10.0;Win64;x64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/83.0.4103.116Safari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('176.222.58.90', '"Mozilla/5.0(Linux;Android9;W-P611-EEA)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.153.227.55', '"Mozilla/5.0(Linux;Android9;SM-J415FN)AppleWebKit/537.36(KHTML,likeGecko)Chrome/77.0.3865.116MobileSafari/537.36EdgA/45.07.2.5059"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('194.156.95.52', '"Mozilla/5.0(Linux;Android10;SM-T510)AppleWebKit/537.36(KHTML,likeGecko)Chrome/77.0.3865.116Safari/537.36EdgA/45.07.2.5059"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.145.161.12', '"Mozilla/5.0(Linux;Android10;SAMSUNGSM-A505FN/A505FNXXU5BTF5)AppleWebKit/537.36(KHTML,likeGecko)SamsungBrowser/12.1Chrome/79.0.3945.136MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.153.227.55', '"Mozilla/5.0(Linux;Android9;SM-J415FN)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('87.247.143.30', '"Mozilla/5.0(WindowsNT6.2;Win64;x64;rv:80.0)Gecko/20100101Firefox/80.0"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.153.227.31', '"Mozilla/5.0(iPhone;CPUiPhoneOS13_7likeMacOSX)AppleWebKit/605.1.15(KHTML,likeGecko)CriOS/85.0.4183.92Mobile/15E148Safari/604.1"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.145.161.6', '"Mozilla/5.0(Linux;Android10;SM-J600FN)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.145.161.6', '"Mozilla/5.0(Linux;Android10;ASUS_Z01RD)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.153.227.31', '"Mozilla/5.0(Linux;Android9;SAMSUNGSM-G955F)AppleWebKit/537.36(KHTML,likeGecko)SamsungBrowser/12.1Chrome/79.0.3945.136MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.51.62', '"Mozilla/5.0(X11;Linuxx86_64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/83.0.4103.116Safari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.153.227.31', '"Mozilla/5.0(Linux;Android9;ZTEBladeV1000)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('194.156.95.20', '"Mozilla/5.0(Linux;Android10;J9110)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.207.154', '"Mozilla/5.0(iPhone;CPUiPhoneOS11_2_5likeMacOSX)AppleWebKit/604.5.6(KHTML,likeGecko)Version/11.0Mobile/15D60Safari/604.1"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.144.0.98', '"Mozilla/5.0(WindowsNT10.0;WOW64;rv:50.0)Gecko/20100101Firefox/50.0"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.51.36', '"Mozilla/5.0(Linux;Android9;LM-K410)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.153.227.55', '"Mozilla/5.0(Linux;Android10;Redmi7A)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.207.154', '"Mozilla/5.0(Linux;Android9;HTCU12+)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.51.36', '"Mozilla/5.0(WindowsNT10.0;WOW64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/84.0.4147.135Safari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.51.36', '"Mozilla/5.0(Linux;Android10;SM-G970F)AppleWebKit/537.36(KHTML,likeGecko)Chrome/83.0.4103.106MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.207.221', '"Mozilla/5.0(Linux;Android8.1.0;GS370)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.144.0.179', '"Mozilla/5.0(WindowsNT10.0)AppleWebKit/537.36(KHTML,likeGecko)Chrome/84.0.4147.125Safari/537.36OPR/70.0.3728.133"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.145.161.12', '"Mozilla/5.0(Macintosh;IntelMacOSX10_14_6)AppleWebKit/537.36(KHTML,likeGecko)Chrome/84.0.4147.125Safari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('176.222.58.90', '"Mozilla/5.0(Linux;Android10;Pixel4)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.138.145.106', '"Mozilla/5.0(Linux;Android8.0.0;AGS2-W09)AppleWebKit/537.36(KHTML,likeGecko)Chrome/84.0.4147.125Safari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.138.145.106', '"Mozilla/5.0(Linux;Android10;SM-N960FBuild/QP1A.190711.020;wv)AppleWebKit/537.36(KHTML,likeGecko)Version/4.0Chrome/85.0.4183.81MobileSafari/537.36EdgW/1.0"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.144.0.179', '"Mozilla/5.0(Linux;Android9;SM-J730FBuild/PPR1.180610.011;wv)AppleWebKit/537.36(KHTML,likeGecko)Version/4.0Chrome/84.0.4147.125MobileSafari/537.36EdgW/1.0"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('54.36.149.8', '"Mozilla/5.0 (compatible; AhrefsBot/7.0; +http://ahrefs.com/robot/)"') accessed these pages
#  ['"GET /index.php?option=com_phocagallery&view=category&id=1%3Aalmhuette-raith&Itemid=53&limitstart=20 HTTP/1.1"']
#
#
#  Client ('45.132.207.154', '"Mozilla/5.0(Linux;U;Android8.1.0;zh-CN;EML-AL00Build/HUAWEIEML-AL00)AppleWebKit/537.36(KHTML,likeGecko)Version/4.0Chrome/57.0.2987.108baidu.sogo.uc.UCBrowser/11.9.4.974UWS/2.13.1.48MobileSafari/537.36AliApp(DingTalk/4.5.11)com.alibaba.a"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.153.227.31', '"Mozilla/5.0(Linux;Android9;SAMSUNGSM-J415FN)AppleWebKit/537.36(KHTML,likeGecko)SamsungBrowser/12.1Chrome/79.0.3945.136MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.51.62', '"Mozilla/5.0(Linux;Android10;SAMSUNGSM-G975F)AppleWebKit/537.36(KHTML,likeGecko)SamsungBrowser/12.1Chrome/79.0.3945.136MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.153.227.55', '"Mozilla/5.0(Macintosh;IntelMacOSX10_13_6)AppleWebKit/605.1.15(KHTML,likeGecko)Version/13.1.1Safari/605.1.15"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('87.247.143.30', '"Mozilla/5.0(Linux;Android9;SM-J730FBuild/PPR1.180610.011;wv)AppleWebKit/537.36(KHTML,likeGecko)Version/4.0Chrome/84.0.4147.125MobileSafari/537.36EdgW/1.0"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('194.156.95.52', '"Mozilla/5.0(Linux;Android10;HRY-LX1)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.138.145.131', '"Mozilla/5.0(WindowsNT10.0)AppleWebKit/537.36(KHTML,likeGecko)Chrome/70.0.3538.102Safari/537.36Edge/18.18363"') accessed these pages
# ...
#
#
#  Client ('45.132.51.62', '"Mozilla/5.0(Linux;Android9;SM-G950FBuild/PPR1.180610.011;wv)AppleWebKit/537.36(KHTML,likeGecko)Version/4.0Chrome/85.0.4183.81MobileSafari/537.36EdgW/1.0"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.138.4.35', '"Mozilla/5.0(Linux;Android9;ZTEBladeV1000)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.207.221', '"Mozilla/5.0(Linux;Android10;CPH1823Build/QP1A.190711.020;wv)AppleWebKit/537.36(KHTML,likeGecko)Version/4.0Chrome/85.0.4183.81MobileSafari/537.36EdgW/1.0"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.51.62', '"Mozilla/5.0(WindowsNT6.1;Win64;x64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/84.0.4147.105Safari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.51.62', '"Mozilla/5.0(Linux;Android10;SM-A415FBuild/QP1A.190711.020;wv)AppleWebKit/537.36(KHTML,likeGecko)Version/4.0Chrome/85.0.4183.81MobileSafari/537.36EdgW/1.0"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('194.156.95.20', '"Mozilla/5.0(Linux;Android10;SAMSUNGSM-G973F/G973FXXU7CTF1)AppleWebKit/537.36(KHTML,likeGecko)SamsungBrowser/12.1Chrome/79.0.3945.136MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.138.4.35', '"Mozilla/5.0(Linux;Android8.1.0;DUB-LX1)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('176.222.58.254', '"Mozilla/5.0(Linux;Android10;SM-G970FBuild/QP1A.190711.020;wv)AppleWebKit/537.36(KHTML,likeGecko)Version/4.0Chrome/85.0.4183.81MobileSafari/537.36EdgW/1.0"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.138.145.106', '"Mozilla/5.0(WindowsNT6.3;Win64;x64;Trident/7.0;rv:11.0)likeGecko"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.144.0.98', '"Mozilla/5.0(WindowsNT6.1;Win64;x64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.102Safari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('194.156.95.52', '"Mozilla/5.0(Linux;Android10;SM-A105FN)AppleWebKit/537.36(KHTML,likeGecko)Chrome/84.0.4147.125MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.51.62', '"Mozilla/5.0(Macintosh;IntelMacOSX11_0)AppleWebKit/605.1.15(KHTML,likeGecko)Version/14.0Safari/605.1.15"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.207.221', '"Mozilla/5.0(Linux;Android10;VOG-L29Build/HUAWEIVOG-L29;wv)AppleWebKit/537.36(KHTML,likeGecko)Version/4.0Chrome/85.0.4183.81MobileSafari/537.36EdgW/1.0"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('87.247.143.30', '"Mozilla/5.0(Linux;Android10;SNE-LX1)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.207.154', '"Mozilla/5.0(Linux;Android7.0;SM-G925F)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('87.247.143.30', '"Mozilla/5.0(Linux;Android10;SM-A105G)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('194.156.95.20', '"Mozilla/5.0(WindowsNT10.0;Win64;x64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/81.0.4044.138Safari/537.36OPR/68.0.3618.206"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.144.0.98', '"Mozilla/5.0(Linux;Android10;SAMSUNGSM-A705FN)AppleWebKit/537.36(KHTML,likeGecko)SamsungBrowser/12.1Chrome/79.0.3945.136MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.138.145.131', '"Mozilla/5.0(Linux;Android9;LM-X520)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.145.161.12', '"Mozilla/5.0(Linux;U;Android10;de-de;Mi9TProBuild/QKQ1.190825.002)AppleWebKit/537.36(KHTML,likeGecko)Version/4.0Chrome/71.0.3578.141MobileSafari/537.36XiaoMi/MiuiBrowser/12.5.2-gn"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('194.156.95.52', '"Mozilla/5.0(Linux;Android9;SM-A530F)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.145.161.12', '"Mozilla/5.0(Linux;Android10;SM-G975FBuild/QP1A.190711.020;wv)AppleWebKit/537.36(KHTML,likeGecko)Version/4.0Chrome/84.0.4147.125MobileSafari/537.36EdgW/1.0"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.144.0.179', '"Mozilla/5.0(WindowsNT6.3;WOW64;Trident/7.0;tb-gmx/2.7.7;rv:11.0)likeGecko"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.138.4.35', '"Mozilla/5.0(iPhone;CPUiPhoneOS13_6_1likeMacOSX)AppleWebKit/605.1.15(KHTML,likeGecko)Version/13.1.2Mobile/15E148Safari/604.1"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.61.164.246', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/12.0 Safari/605.1.15"') accessed these pages
#  ['"GET / HTTP/1.0"']
#
#
#  Client ('45.145.161.12', '"Mozilla/5.0(X11;Linuxx86_64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/84.0.4147.135Safari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.145.161.12', '"Mozilla/5.0(X11;Linuxx86_64;rv:52.0)Gecko/20100101Firefox/52.0"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.207.221', '"Mozilla/5.0(WindowsNT6.3;Win64;x64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/84.0.4147.105Safari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.138.4.35', '"Mozilla/5.0(Linux;Android7.1.1;SAMSUNGSM-J510FN)AppleWebKit/537.36(KHTML,likeGecko)SamsungBrowser/12.1Chrome/79.0.3945.136MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.207.221', '"Mozilla/5.0(WindowsNT10.0;rv:43.0)Gecko/20100101Firefox/43.0anonymizedbyAbelssoft1600746919"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.138.145.106', '"Mozilla/5.0(WindowsNT6.1)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.102Safari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.138.4.22', '"Mozilla/5.0(Linux;Android9;SM-J415FN)AppleWebKit/537.36(KHTML,likeGecko)Chrome/77.0.3865.116MobileSafari/537.36EdgA/45.07.2.5057"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.145.161.12', '"Mozilla/5.0(Mobile;WindowsPhone8.1;Android4.0;ARM;Trident/7.0;Touch;rv:11.0;IEMobile/11.0;NOKIA;Lumia520)likeiPhoneOS7_0_3MacOSXAppleWebKit/537(KHTML,likeGecko)MobileSafari/537"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('176.222.58.254', '"Mozilla/5.0(WindowsNT10.0;rv:67.0)Gecko/20100101Firefox/67.0anonymizedbyAbelssoft509110158"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.145.161.12', '"Mozilla/5.0(WindowsNT6.3;WOW64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/84.0.4147.135Safari/537.36OPR/70.0.3728.178"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('72.29.66.216', '"Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/533.4 (KHTML, like Gecko) Chrome/5.0.375.99 Safari/533.4"') accessed these pages
#  ['"GET /libraries/joomla/template/mark.php HTTP/1.1"', '"GET /media/sitemap.php HTTP/1.1"']
#
#
#  Client ('45.144.0.179', '"Mozilla/5.0(WindowsNT10.0;Win64;x64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/81.0.4044.138Safari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.138.145.131', '"Mozilla/5.0(iPad;CPUOS13_6likeMacOSX)AppleWebKit/605.1.15(KHTML,likeGecko)GSA/123.4.330040034Mobile/15E148Safari/604.1"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.138.4.35', '"Mozilla/5.0(WindowsNT6.1;WOW64;rv:68.0)Gecko/20100101Firefox/68.0"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('176.222.58.254', '"Mozilla/5.0(Linux;Android9;ONEPLUSA3010)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('87.247.143.24', '"Mozilla/5.0(Linux;Android10;SM-N960F)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.81MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('87.247.143.24', '"Mozilla/5.0(Linux;Android10;SM-A405FN)AppleWebKit/537.36(KHTML,likeGecko)Chrome/85.0.4183.101MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.132.207.221', '"Mozilla/5.0(Linux;Android5.1;HUAWEILYO-L21)AppleWebKit/537.36(KHTML,likeGecko)Chrome/80.0.3987.99MobileSafari/537.36"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('176.222.58.254', '"Mozilla/5.0(Mobile;WindowsPhone8.1;Android4.0;ARM;Trident/7.0;Touch;rv:11.0;IEMobile/11.0;NOKIA;Lumia520)likeiPhoneOS7_0_3MacOSXAppleWebKit/537(KHTML,likeGecko)MobileSafari/537"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
#
#
#  Client ('45.138.145.131', '"Mozilla/5.0(Linux;Android9;SM-N950FBuild/PPR1.180610.011;wv)AppleWebKit/537.36(KHTML,likeGecko)Version/4.0Chrome/85.0.4183.81MobileSafari/537.36EdgW/1.0"') accessed these pages
#  ['"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"GET /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"', '"POST /index.php?option=com_contact&view=contact&id=1 HTTP/1.1"']
